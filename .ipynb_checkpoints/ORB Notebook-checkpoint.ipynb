# %%
import cv2
import matplotlib.pyplot as plt
from time import time
from skimage.feature import plot_matches
from skimage.transform import pyramid_gaussian

from utils import *

# %matplotlib inline

# %% [markdown]
# ## Blur Test

# %%
# multi-scale
N_LAYERS = 16
DOWNSCALE = 1.2

img1 = cv2.imread('images/car.jpg')
original_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
gray1 = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
gray1 = cv2.GaussianBlur(gray1, (15,15), 0)
grays1 = list(pyramid_gaussian(gray1, downscale=DOWNSCALE, max_layer=N_LAYERS, multichannel=False))

img2 = cv2.imread('images/car.jpg')
original_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
gray2 = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
grays2 = list(pyramid_gaussian(gray2, downscale=DOWNSCALE, max_layer=N_LAYERS, multichannel=False))

scales = [DOWNSCALE**i for i in range(N_LAYERS)]
print('scales: ', scales, '\n')
features_img1 = np.copy(img1)
features_img2 = np.copy(img2)

kps1 = []
kps2 = []

ds1 = []
ds2 = []

for i in range(N_LAYERS):
    print('pyramid layer: ', i)
    print('scales[i]: ', scales[i])
    scale_coeff1 = (gray1.shape[1]/grays1[i].shape[1], gray1.shape[0]/grays1[i].shape[0])
    scale_coeff2 = (gray2.shape[1]/grays2[i].shape[1], gray2.shape[0]/grays2[i].shape[0])
    
    print('scale_coeff1: ', scale_coeff1)
    print('scale_coeff2: ', scale_coeff2)
    
    print('grays1[i] shape: ', grays1[i].shape)
    print('grays2[i] shape: ', grays2[i].shape)
    
    scale_kp1 = FAST(grays1[i], N=9, threshold=0.1, nms_window=3)
    scale_kp2 = FAST(grays2[i], N=9, threshold=0.1, nms_window=3)
    
    print('kp1: ', len(scale_kp1))
    print('kp2: ', len(scale_kp2))
    
    for keypoint in scale_kp1:
        features_img1 = cv2.circle(features_img1, tuple(np.round(keypoint*scale_coeff1).astype(np.int32)), int(3*scales[i]), (0,255,0), 1)
    for keypoint in scale_kp2:
        features_img2 = cv2.circle(features_img2, tuple(np.round(keypoint*scale_coeff2).astype(np.int32)), int(3*scales[i]), (0,255,0), 1)
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(grays1[i], cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(features_img1)

    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(grays2[i], cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(features_img2)
    
#     orientations1, orientations2 = None, None
    orientations1 = corner_orientations(grays1[i], scale_kp1)
    orientations2 = corner_orientations(grays2[i], scale_kp2)
    
    if not (len(scale_kp1) == 0 or len(scale_kp2) == 1):
        # avoding errors when no keypoints are computed (happens with small scales - higher pyramid layers)
        kps1.append(np.round(scale_kp1*scale_coeff1).astype(np.int32))
        kps2.append(np.round(scale_kp2*scale_coeff2).astype(np.int32))
        
        d1 = BRIEF(grays1[i], scale_kp1, orientations=orientations1, mode='uniform', n=512)
        d2 = BRIEF(grays2[i], scale_kp2, orientations=orientations2, mode='uniform', n=512)
        ds1.append(d1)
        ds2.append(d2)
    
    plt.show()
    print('-'*50)


plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(features_img1)
plt.subplot(1,2,2)
plt.imshow(features_img2)
plt.show()
# Out:
# scales:  [1.0, 1.2, 1.44, 1.7279999999999998, 2.0736, 2.4883199999999994, 2.9859839999999993, 3.583180799999999, 4.2998169599999985, 5.1597803519999985, 6.191736422399997, 7.430083706879997, 8.916100448255996, 10.699320537907195, 12.839184645488633, 15.40702157458636]
#
# pyramid layer:  0
# scales[i]:  1.0
# scale_coeff1:  (1.0, 1.0)
# scale_coeff2:  (1.0, 1.0)
# grays1[i] shape:  (450, 800)
# grays2[i] shape:  (450, 800)
# kp1:  1101
# kp2:  4501
# --------------------------------------------------
# pyramid layer:  1
# scales[i]:  1.2
# scale_coeff1:  (1.199400299850075, 1.2)
# scale_coeff2:  (1.199400299850075, 1.2)
# grays1[i] shape:  (375, 667)
# grays2[i] shape:  (375, 667)
# kp1:  1149
# kp2:  3304
# --------------------------------------------------
# pyramid layer:  2
# scales[i]:  1.44
# scale_coeff1:  (1.4388489208633093, 1.4376996805111821)
# scale_coeff2:  (1.4388489208633093, 1.4376996805111821)
# grays1[i] shape:  (313, 556)
# grays2[i] shape:  (313, 556)
# kp1:  1128
# kp2:  2430
# --------------------------------------------------
# pyramid layer:  3
# scales[i]:  1.7279999999999998
# scale_coeff1:  (1.7241379310344827, 1.7241379310344827)
# scale_coeff2:  (1.7241379310344827, 1.7241379310344827)
# grays1[i] shape:  (261, 464)
# grays2[i] shape:  (261, 464)
# kp1:  1071
# kp2:  1848
# --------------------------------------------------
# pyramid layer:  4
# scales[i]:  2.0736
# scale_coeff1:  (2.0671834625322996, 2.0642201834862384)
# scale_coeff2:  (2.0671834625322996, 2.0642201834862384)
# grays1[i] shape:  (218, 387)
# grays2[i] shape:  (218, 387)
# kp1:  900
# kp2:  1281
# --------------------------------------------------
# pyramid layer:  5
# scales[i]:  2.4883199999999994
# scale_coeff1:  (2.476780185758514, 2.4725274725274726)
# scale_coeff2:  (2.476780185758514, 2.4725274725274726)
# grays1[i] shape:  (182, 323)
# grays2[i] shape:  (182, 323)
# kp1:  697
# kp2:  912
# --------------------------------------------------
# pyramid layer:  6
# scales[i]:  2.9859839999999993
# scale_coeff1:  (2.962962962962963, 2.960526315789474)
# scale_coeff2:  (2.962962962962963, 2.960526315789474)
# grays1[i] shape:  (152, 270)
# grays2[i] shape:  (152, 270)
# kp1:  571
# kp2:  688
# --------------------------------------------------
# pyramid layer:  7
# scales[i]:  3.583180799999999
# scale_coeff1:  (3.5555555555555554, 3.543307086614173)
# scale_coeff2:  (3.5555555555555554, 3.543307086614173)
# grays1[i] shape:  (127, 225)
# grays2[i] shape:  (127, 225)
# kp1:  434
# kp2:  477
# --------------------------------------------------
# pyramid layer:  8
# scales[i]:  4.2998169599999985
# scale_coeff1:  (4.25531914893617, 4.245283018867925)
# scale_coeff2:  (4.25531914893617, 4.245283018867925)
# grays1[i] shape:  (106, 188)
# grays2[i] shape:  (106, 188)
# kp1:  334
# kp2:  353
# --------------------------------------------------
# pyramid layer:  9
# scales[i]:  5.1597803519999985
# scale_coeff1:  (5.095541401273885, 5.056179775280899)
# scale_coeff2:  (5.095541401273885, 5.056179775280899)
# grays1[i] shape:  (89, 157)
# grays2[i] shape:  (89, 157)
# kp1:  249
# kp2:  255
# --------------------------------------------------
# pyramid layer:  10
# scales[i]:  6.191736422399997
# scale_coeff1:  (6.106870229007634, 6.0)
# scale_coeff2:  (6.106870229007634, 6.0)
# grays1[i] shape:  (75, 131)
# grays2[i] shape:  (75, 131)
# kp1:  186
# kp2:  185
# --------------------------------------------------
# pyramid layer:  11
# scales[i]:  7.430083706879997
# scale_coeff1:  (7.2727272727272725, 7.142857142857143)
# scale_coeff2:  (7.2727272727272725, 7.142857142857143)
# grays1[i] shape:  (63, 110)
# grays2[i] shape:  (63, 110)
# kp1:  129
# kp2:  134
# --------------------------------------------------
# pyramid layer:  12
# scales[i]:  8.916100448255996
# scale_coeff1:  (8.695652173913043, 8.49056603773585)
# scale_coeff2:  (8.695652173913043, 8.49056603773585)
# grays1[i] shape:  (53, 92)
# grays2[i] shape:  (53, 92)
# kp1:  101
# kp2:  101
# --------------------------------------------------
# pyramid layer:  13
# scales[i]:  10.699320537907195
# scale_coeff1:  (10.38961038961039, 10.0)
# scale_coeff2:  (10.38961038961039, 10.0)
# grays1[i] shape:  (45, 77)
# grays2[i] shape:  (45, 77)
# kp1:  85
# kp2:  80
# --------------------------------------------------
# pyramid layer:  14
# scales[i]:  12.839184645488633
# scale_coeff1:  (12.307692307692308, 11.842105263157896)
# scale_coeff2:  (12.307692307692308, 11.842105263157896)
# grays1[i] shape:  (38, 65)
# grays2[i] shape:  (38, 65)
# kp1:  64
# kp2:  62
# --------------------------------------------------
# pyramid layer:  15
# scales[i]:  15.40702157458636
# scale_coeff1:  (14.545454545454545, 14.0625)
# scale_coeff2:  (14.545454545454545, 14.0625)
# grays1[i] shape:  (32, 55)
# grays2[i] shape:  (32, 55)
# kp1:  40
# kp2:  39
# --------------------------------------------------

# %%
scale_kps1 = np.vstack(kps1)
scale_kps2 = np.vstack(kps2)

scale_ds1 = np.vstack(ds1)
scale_ds2 = np.vstack(ds2)

# Matching is done after computing all keypoints and descriptors to allow for
# the sorting of all descriptors computed on all scales
scale_ms = match(scale_ds1, scale_ds2, cross_check=True)

print('total matches: ', len(scale_ms))

fig = plt.figure(figsize=(20.0, 30.0))
ax = fig.add_subplot(1,1,1)
plot_matches(ax, img1, img2, np.flip(scale_kps1, 1), np.flip(scale_kps2, 1), scale_ms[:50], 
             alignment='horizontal', only_matches=True)
# Out:
# total matches:  3940

# %% [markdown]
# ## Scale Invarient

# %%
# Trying multi-scale
N_LAYERS = 16
DOWNSCALE = 1.2

img1 = cv2.imread('images/chess3.jpg')
original_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
gray1 = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
grays1 = list(pyramid_gaussian(gray1, downscale=DOWNSCALE, max_layer=N_LAYERS, multichannel=False))

img2 = cv2.imread('images/chess.jpg')
original_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
gray2 = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
grays2 = list(pyramid_gaussian(gray2, downscale=DOWNSCALE, max_layer=N_LAYERS, multichannel=False))

scales = [DOWNSCALE**i for i in range(N_LAYERS)]
print('scales: ', scales, '\n')
features_img1 = np.copy(img1)
features_img2 = np.copy(img2)

kps1 = []
kps2 = []

ds1 = []
ds2 = []

for i in range(N_LAYERS):
    print('pyramid layer: ', i)
    print('scales[i]: ', scales[i])
    scale_coeff1 = (gray1.shape[1]/grays1[i].shape[1], gray1.shape[0]/grays1[i].shape[0])
    scale_coeff2 = (gray2.shape[1]/grays2[i].shape[1], gray2.shape[0]/grays2[i].shape[0])
    
    print('scale_coeff1: ', scale_coeff1)
    print('scale_coeff2: ', scale_coeff2)
    
    print('grays1[i] shape: ', grays1[i].shape)
    print('grays2[i] shape: ', grays2[i].shape)
    
    scale_kp1 = FAST(grays1[i], N=9, threshold=0.1, nms_window=3)
    scale_kp2 = FAST(grays2[i], N=9, threshold=0.1, nms_window=3)
    
    print('kp1: ', len(scale_kp1))
    print('kp2: ', len(scale_kp2))
    
    for keypoint in scale_kp1:
        features_img1 = cv2.circle(features_img1, tuple(np.round(keypoint*scale_coeff1).astype(np.int32)), int(3*scales[i]), (0,255,0), 1)
    for keypoint in scale_kp2:
        features_img2 = cv2.circle(features_img2, tuple(np.round(keypoint*scale_coeff2).astype(np.int32)), int(3*scales[i]), (0,255,0), 1)
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(grays1[i], cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(features_img1)

    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(grays2[i], cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(features_img2)
    
#     orientations1, orientations2 = None, None
    orientations1 = corner_orientations(grays1[i], scale_kp1)
    orientations2 = corner_orientations(grays2[i], scale_kp2)
    
    if not (len(scale_kp1) == 0 or len(scale_kp2) == 1):
        # avoding errors when no keypoints are computed (happens with small scales - higher pyramid layers)
        kps1.append(np.round(scale_kp1*scale_coeff1).astype(np.int32))
        kps2.append(np.round(scale_kp2*scale_coeff2).astype(np.int32))
        
        d1 = BRIEF(grays1[i], scale_kp1, orientations=orientations1, mode='uniform', n=512)
        d2 = BRIEF(grays2[i], scale_kp2, orientations=orientations2, mode='uniform', n=512)
        ds1.append(d1)
        ds2.append(d2)
    
    plt.show()
    print('-'*50)


plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(features_img1)
plt.subplot(1,2,2)
plt.imshow(features_img2)
plt.show()
# Out:
# scales:  [1.0, 1.2, 1.44, 1.7279999999999998, 2.0736, 2.4883199999999994, 2.9859839999999993, 3.583180799999999, 4.2998169599999985, 5.1597803519999985, 6.191736422399997, 7.430083706879997, 8.916100448255996, 10.699320537907195, 12.839184645488633, 15.40702157458636]
#
# pyramid layer:  0
# scales[i]:  1.0
# scale_coeff1:  (1.0, 1.0)
# scale_coeff2:  (1.0, 1.0)
# grays1[i] shape:  (300, 156)
# grays2[i] shape:  (720, 1280)
# kp1:  169
# kp2:  1268
# --------------------------------------------------
# pyramid layer:  1
# scales[i]:  1.2
# scale_coeff1:  (1.2, 1.2)
# scale_coeff2:  (1.1996251171508903, 1.2)
# grays1[i] shape:  (250, 130)
# grays2[i] shape:  (600, 1067)
# kp1:  112
# kp2:  989
# --------------------------------------------------
# pyramid layer:  2
# scales[i]:  1.44
# scale_coeff1:  (1.4311926605504588, 1.4354066985645932)
# scale_coeff2:  (1.4382022471910112, 1.44)
# grays1[i] shape:  (209, 109)
# grays2[i] shape:  (500, 890)
# kp1:  80
# kp2:  895
# --------------------------------------------------
# pyramid layer:  3
# scales[i]:  1.7279999999999998
# scale_coeff1:  (1.7142857142857142, 1.7142857142857142)
# scale_coeff2:  (1.725067385444744, 1.7266187050359711)
# grays1[i] shape:  (175, 91)
# grays2[i] shape:  (417, 742)
# kp1:  61
# kp2:  810
# --------------------------------------------------
# pyramid layer:  4
# scales[i]:  2.0736
# scale_coeff1:  (2.0526315789473686, 2.0547945205479454)
# scale_coeff2:  (2.0678513731825525, 2.0689655172413794)
# grays1[i] shape:  (146, 76)
# grays2[i] shape:  (348, 619)
# kp1:  46
# kp2:  729
# --------------------------------------------------
# pyramid layer:  5
# scales[i]:  2.4883199999999994
# scale_coeff1:  (2.4375, 2.459016393442623)
# scale_coeff2:  (2.4806201550387597, 2.4827586206896552)
# grays1[i] shape:  (122, 64)
# grays2[i] shape:  (290, 516)
# kp1:  47
# kp2:  654
# --------------------------------------------------
# pyramid layer:  6
# scales[i]:  2.9859839999999993
# scale_coeff1:  (2.888888888888889, 2.9411764705882355)
# scale_coeff2:  (2.9767441860465116, 2.975206611570248)
# grays1[i] shape:  (102, 54)
# grays2[i] shape:  (242, 430)
# kp1:  33
# kp2:  578
# --------------------------------------------------
# pyramid layer:  7
# scales[i]:  3.583180799999999
# scale_coeff1:  (3.466666666666667, 3.5294117647058822)
# scale_coeff2:  (3.565459610027855, 3.5643564356435644)
# grays1[i] shape:  (85, 45)
# grays2[i] shape:  (202, 359)
# kp1:  28
# kp2:  535
# --------------------------------------------------
# pyramid layer:  8
# scales[i]:  4.2998169599999985
# scale_coeff1:  (4.105263157894737, 4.225352112676056)
# scale_coeff2:  (4.266666666666667, 4.260355029585799)
# grays1[i] shape:  (71, 38)
# grays2[i] shape:  (169, 300)
# kp1:  21
# kp2:  513
# --------------------------------------------------
# pyramid layer:  9
# scales[i]:  5.1597803519999985
# scale_coeff1:  (4.875, 5.0)
# scale_coeff2:  (5.12, 5.1063829787234045)
# grays1[i] shape:  (60, 32)
# grays2[i] shape:  (141, 250)
# kp1:  25
# kp2:  488
# --------------------------------------------------
# pyramid layer:  10
# scales[i]:  6.191736422399997
# scale_coeff1:  (5.777777777777778, 6.0)
# scale_coeff2:  (6.124401913875598, 6.101694915254237)
# grays1[i] shape:  (50, 27)
# grays2[i] shape:  (118, 209)
# kp1:  19
# kp2:  391
# --------------------------------------------------
# pyramid layer:  11
# scales[i]:  7.430083706879997
# scale_coeff1:  (6.782608695652174, 7.142857142857143)
# scale_coeff2:  (7.314285714285714, 7.2727272727272725)
# grays1[i] shape:  (42, 23)
# grays2[i] shape:  (99, 175)
# kp1:  15
# kp2:  321
# --------------------------------------------------
# pyramid layer:  12
# scales[i]:  8.916100448255996
# scale_coeff1:  (7.8, 8.571428571428571)
# scale_coeff2:  (8.767123287671232, 8.674698795180722)
# grays1[i] shape:  (35, 20)
# grays2[i] shape:  (83, 146)
# kp1:  13
# kp2:  264
# --------------------------------------------------
# pyramid layer:  13
# scales[i]:  10.699320537907195
# scale_coeff1:  (9.176470588235293, 10.0)
# scale_coeff2:  (10.491803278688524, 10.285714285714286)
# grays1[i] shape:  (30, 17)
# grays2[i] shape:  (70, 122)
# kp1:  9
# kp2:  202
# --------------------------------------------------
# pyramid layer:  14
# scales[i]:  12.839184645488633
# scale_coeff1:  (10.4, 12.0)
# scale_coeff2:  (12.549019607843137, 12.203389830508474)
# grays1[i] shape:  (25, 15)
# grays2[i] shape:  (59, 102)
# kp1:  5
# kp2:  146
# --------------------------------------------------
# pyramid layer:  15
# scales[i]:  15.40702157458636
# scale_coeff1:  (12.0, 14.285714285714286)
# scale_coeff2:  (15.058823529411764, 14.4)
# grays1[i] shape:  (21, 13)
# grays2[i] shape:  (50, 85)
# kp1:  3
# kp2:  112
# --------------------------------------------------

# %%
scale_kps1 = np.vstack(kps1)
scale_kps2 = np.vstack(kps2)

scale_ds1 = np.vstack(ds1)
scale_ds2 = np.vstack(ds2)

# Matching is done after computing all keypoints and descriptors to allow for
# the sorting of all descriptors computed on all scales
scale_ms = match(scale_ds1, scale_ds2, cross_check=True)

print('total matches: ', len(scale_ms))

fig = plt.figure(figsize=(20.0, 30.0))
ax = fig.add_subplot(1,1,1)
plot_matches(ax, img1, img2, np.flip(scale_kps1, 1), np.flip(scale_kps2, 1), scale_ms[:10], 
             alignment='horizontal', only_matches=True)
# Out:
# total matches:  406
